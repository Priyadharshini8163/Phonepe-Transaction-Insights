# %% [markdown]
# ### GITHUB CLONING FOR PHONEPE TO DOWNLOAD DATA

# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# Updating files:  18% (1632/9029)
# Updating files:  19% (1716/9029)
# Updating files:  20% (1806/9029)
# Updating files:  21% (1897/9029)
# Updating files:  22% (1987/9029)
# Updating files:  23% (2077/9029)
# Updating files:  24% (2167/9029)
# Updating files:  25% (2258/9029)
# Updating files:  26% (2348/9029)
# Updating files:  27% (2438/9029)
# Updating files:  28% (2529/9029)
# Updating files:  29% (2619/9029)
# Updating files:  30% (2709/9029)
# Updating files:  31% (2799/9029)
# Updating files:  31% (2865/9029)
# Updating files:  32% (2890/9029)
# Updating files:  33% (2980/9029)
# Updating files:  34% (3070/9029)
# Updating files:  35% (3161/9029)
# Updating files:  36% (3251/9029)
# Updating files:  37% (3341/9029)
# Updating files:  38% (3432/9029)
# Updating files:  39% (3522/9029)
# Updating files:  40% (3612/9029)
# Updating files:  41% (3702/9029)
# Updating files:  42% (3793/9029)
# Updating files:  42% (3808/9029)
# ...

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import numpy as np
import json
import os
import pymysql

# %% [markdown]
# ### AGGREGATED - TRANSACTION DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//aggregated//transaction//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Transaction=pd.DataFrame(clm)
Agg_Transaction
# Out:
#                           State  Year  Quater          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 5029                west-bengal  2024       4         Merchant payments
# 5030                west-bengal  2024       4     Peer-to-peer payments
# 5031                west-bengal  2024       4  Recharge & bill payments
# 5032                west-bengal  2024       4        Financial Services
# 5033                west-bengal  2024       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %% [markdown]
# ### AGGREGATED - INSURANCE DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//aggregated//insurance//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Payment_type':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Payment_type'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Insurance=pd.DataFrame(clm)
Agg_Insurance
# Out:
#                          State  Year  Quater Payment_type  Insurance_count  \
# 0    andaman-&-nicobar-islands  2020       2    Insurance                6
# 1    andaman-&-nicobar-islands  2020       3    Insurance               41
# 2    andaman-&-nicobar-islands  2020       4    Insurance              124
# 3    andaman-&-nicobar-islands  2021       1    Insurance              225
# 4    andaman-&-nicobar-islands  2021       2    Insurance              137
# ..                         ...   ...     ...          ...              ...
# 677                west-bengal  2023       4    Insurance            72712
# 678                west-bengal  2024       1    Insurance            79576
# 679                west-bengal  2024       2    Insurance            67048
# 680                west-bengal  2024       3    Insurance            77158
# 681                west-bengal  2024       4    Insurance            91719
#
#      Insurance_amount
# 0              1360.0
# ...

# %% [markdown]
# ### AGGREGATED - USERS DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//aggregated//user//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Users_brand':[], 'Users_count':[], 'Users_percentage':[], 'RegisteredUsers':[], 'AppOpens':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            aggregated_data = D.get('data', {}).get('aggregated', {})
            registeredUsers = aggregated_data.get('registeredUsers', 0)
            appOpens = aggregated_data.get('appOpens', 0)

            if D['data'].get('usersByDevice') is not None:
              for z in D['data']['usersByDevice']:
                brand = z.get('brand', 'Unknown')
                count = z.get('count', 0)
                percentage = z.get('percentage', 0.0)
                clm['Users_brand'].append(brand)
                clm['Users_count'].append(count)
                clm['Users_percentage'].append(percentage)
                clm['RegisteredUsers'].append(registeredUsers)
                clm['AppOpens'].append(appOpens)

                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Users=pd.DataFrame(clm)
Agg_Users
# Out:
#                           State  Year  Quater Users_brand  Users_count  \
# 0     andaman-&-nicobar-islands  2018       1      Xiaomi         1665
# 1     andaman-&-nicobar-islands  2018       1     Samsung         1445
# 2     andaman-&-nicobar-islands  2018       1        Vivo          982
# 3     andaman-&-nicobar-islands  2018       1        Oppo          501
# 4     andaman-&-nicobar-islands  2018       1     OnePlus          332
# ...                         ...   ...     ...         ...          ...
# 6727                west-bengal  2022       1      Lenovo       330017
# 6728                west-bengal  2022       1     Infinix       284678
# 6729                west-bengal  2022       1        Asus       280347
# 6730                west-bengal  2022       1       Apple       277752
# 6731                west-bengal  2022       1      Others      2196334
#
#       Users_percentage  RegisteredUsers   AppOpens
# 0             0.247033             6740          0
# ...

# %% [markdown]
# ### MAP - TRANSACTION HOVER  DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//map//transaction//hover//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_Hover_name':[], 'Transaction_Hover_count':[], 'Transaction_Hover_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Transaction_Hover_name'].append(Name)
              clm['Transaction_Hover_count'].append(count)
              clm['Transaction_Hover_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Transaction_Hover=pd.DataFrame(clm)
Map_Transaction_Hover
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20599                west-bengal  2024       4
# 20600                west-bengal  2024       4
# 20601                west-bengal  2024       4
# 20602                west-bengal  2024       4
# 20603                west-bengal  2024       4
#
#                   Transaction_Hover_name  Transaction_Hover_count  \
# 0      north and middle andaman district                      442
# 1                 south andaman district                     5688
# 2                      nicobars district                      528
# 3      north and middle andaman district                      825
# ...

# %% [markdown]
# ### MAP - INSURANCE HOVER DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//map//insurance//hover//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Insurance_Hover_name':[], 'Insurance_Hover_count':[], 'Insurance_Hover_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Insurance_Hover_name'].append(Name)
              clm['Insurance_Hover_count'].append(count)
              clm['Insurance_Hover_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Insurance_Hover=pd.DataFrame(clm)
Map_Insurance_Hover
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2020       2
# 1      andaman-&-nicobar-islands  2020       2
# 2      andaman-&-nicobar-islands  2020       3
# 3      andaman-&-nicobar-islands  2020       3
# 4      andaman-&-nicobar-islands  2020       3
# ...                          ...   ...     ...
# 13871                west-bengal  2024       4
# 13872                west-bengal  2024       4
# 13873                west-bengal  2024       4
# 13874                west-bengal  2024       4
# 13875                west-bengal  2024       4
#
#                     Insurance_Hover_name  Insurance_Hover_count  \
# 0                 south andaman district                      3
# 1                      nicobars district                      3
# 2      north and middle andaman district                      1
# 3                 south andaman district                     35
# 4                      nicobars district                      5
# ...

# %% [markdown]
# ### MAP - USERS HOVER DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//map//user//hover//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'District':[],'Registered_Users':[], 'App_Opens':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for zz,z in D['data']['hoverData'].items():
              registeredUsers=z['registeredUsers']
              appOpens=z['appOpens']
              clm['Registered_Users'].append(registeredUsers)
              clm['App_Opens'].append(appOpens)
              clm['State'].append(i)
              clm['District'].append(zz)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_User_Hover=pd.DataFrame(clm)
Map_User_Hover
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20603                west-bengal  2024       4
# 20604                west-bengal  2024       4
# 20605                west-bengal  2024       4
# 20606                west-bengal  2024       4
# 20607                west-bengal  2024       4
#
#                                 District  Registered_Users  App_Opens
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %% [markdown]
# ### TOP - TRANSACTION DISTRICT LEVEL DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//top//transaction//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_District':[], 'Transaction_District_count':[], 'Transaction_District_amount':[],}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:          
              District=z['entityName']
              Districtcount=z['metric']['count']
              Districtamount=z['metric']['amount']
              clm['Transaction_District'].append(District)
              clm['Transaction_District_count'].append(Districtcount)
              clm['Transaction_District_amount'].append(Districtamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Trans_District=pd.DataFrame(clm)
Top_Trans_District
# Out:
#                           State  Year  Quater      Transaction_District  \
# 0     andaman-&-nicobar-islands  2018       1             south andaman
# 1     andaman-&-nicobar-islands  2018       1                  nicobars
# 2     andaman-&-nicobar-islands  2018       1  north and middle andaman
# 3     andaman-&-nicobar-islands  2018       2             south andaman
# 4     andaman-&-nicobar-islands  2018       2                  nicobars
# ...                         ...   ...     ...                       ...
# 8291                west-bengal  2024       4                    howrah
# 8292                west-bengal  2024       4                     nadia
# 8293                west-bengal  2024       4                     malda
# 8294                west-bengal  2024       4                   hooghly
# 8295                west-bengal  2024       4         paschim medinipur
#
#       Transaction_District_count  Transaction_District_amount
# ...

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//top//transaction//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_Pincode':[], 'Transaction_Pincode_count':[], 'Transaction_Pincode_amount':[],}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:          
              Pincode=z['entityName']
              Pincodecount=z['metric']['count']
              Pincodeamount=z['metric']['amount']
              clm['Transaction_Pincode'].append(Pincode)
              clm['Transaction_Pincode_count'].append(Pincodecount)
              clm['Transaction_Pincode_amount'].append(Pincodeamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Trans_Pincode=pd.DataFrame(clm)
Top_Trans_Pincode
# Out:
#                           State  Year  Quater Transaction_Pincode  \
# 0     andaman-&-nicobar-islands  2018       1              744101
# 1     andaman-&-nicobar-islands  2018       1              744103
# 2     andaman-&-nicobar-islands  2018       1              744102
# 3     andaman-&-nicobar-islands  2018       1              744105
# 4     andaman-&-nicobar-islands  2018       1              744104
# ...                         ...   ...     ...                 ...
# 9994                west-bengal  2024       4              711101
# 9995                west-bengal  2024       4              700059
# 9996                west-bengal  2024       4              700039
# 9997                west-bengal  2024       4              734001
# 9998                west-bengal  2024       4              733134
#
#       Transaction_Pincode_count  Transaction_Pincode_amount
# 0                          1622                2.769298e+06
# ...

# %% [markdown]
# ### TOP - INSURANCE DISTRICT LEVEL DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//top//insurance//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Insurance_District':[], 'Insurance_District_count':[], 'Insurance_District_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j) 
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              District=z['entityName']
              Districtcount=z['metric']['count']
              Districtamount=z['metric']['amount']
              clm['Insurance_District'].append(District)
              clm['Insurance_District_count'].append(Districtcount)
              clm['Insurance_District_amount'].append(Districtamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Ins_District=pd.DataFrame(clm)
Top_Ins_District
# Out:
#                           State  Year  Quater        Insurance_District  \
# 0     andaman-&-nicobar-islands  2020       2                  nicobars
# 1     andaman-&-nicobar-islands  2020       2             south andaman
# 2     andaman-&-nicobar-islands  2020       3             south andaman
# 3     andaman-&-nicobar-islands  2020       3                  nicobars
# 4     andaman-&-nicobar-islands  2020       3  north and middle andaman
# ...                         ...   ...     ...                       ...
# 5603                west-bengal  2024       4         paschim bardhaman
# 5604                west-bengal  2024       4         paschim medinipur
# 5605                west-bengal  2024       4                     malda
# 5606                west-bengal  2024       4                     nadia
# 5607                west-bengal  2024       4           purba bardhaman
#
#       Insurance_District_count  Insurance_District_amount
# ...

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//top//insurance//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Insurance_Pincode':[], 'Insurance_Pincode_count':[], 'Insurance_Pincode_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j) 
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)            
            for z in D['data']['pincodes']:
              Pincode=z['entityName']
              Pincodecount=z['metric']['count']
              Pincodeamount=z['metric']['amount']
              clm['Insurance_Pincode'].append(Pincode)
              clm['Insurance_Pincode_count'].append(Pincodecount)
              clm['Insurance_Pincode_amount'].append(Pincodeamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Ins_Pincode=pd.DataFrame(clm)
Top_Ins_Pincode
# Out:
#                           State  Year  Quater Insurance_Pincode  \
# 0     andaman-&-nicobar-islands  2020       2            744301
# 1     andaman-&-nicobar-islands  2020       2            744104
# 2     andaman-&-nicobar-islands  2020       2            744101
# 3     andaman-&-nicobar-islands  2020       3            744112
# 4     andaman-&-nicobar-islands  2020       3            744105
# ...                         ...   ...     ...               ...
# 6663                west-bengal  2024       4            711101
# 6664                west-bengal  2024       4            700091
# 6665                west-bengal  2024       4            700150
# 6666                west-bengal  2024       4            700039
# 6667                west-bengal  2024       4            700156
#
#       Insurance_Pincode_count  Insurance_Pincode_amount
# 0                           3                     565.0
# 1                           2                     513.0
# ...

# %% [markdown]
# ### TOP - USERS DISTRICT LEVEL DATA

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//top//user//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'User_District':[], 'User_DistrictRegisteredUsers':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              District=z['name']
              DistrictregisteredUsers=z['registeredUsers']
              clm['User_District'].append(District)
              clm['User_DistrictRegisteredUsers'].append(DistrictregisteredUsers)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_User_District=pd.DataFrame(clm)
Top_User_District
# Out:
#                           State  Year  Quater             User_District  \
# 0     andaman-&-nicobar-islands  2018       1             south andaman
# 1     andaman-&-nicobar-islands  2018       1  north and middle andaman
# 2     andaman-&-nicobar-islands  2018       1                  nicobars
# 3     andaman-&-nicobar-islands  2018       2             south andaman
# 4     andaman-&-nicobar-islands  2018       2  north and middle andaman
# ...                         ...   ...     ...                       ...
# 8291                west-bengal  2024       4                   hooghly
# 8292                west-bengal  2024       4                     nadia
# 8293                west-bengal  2024       4           purba medinipur
# 8294                west-bengal  2024       4         paschim medinipur
# 8295                west-bengal  2024       4         paschim bardhaman
#
#       User_DistrictRegisteredUsers
# 0                             5846
# ...

# %%
#This is to direct the path to get the data as states
path="C://Users//conta//OneDrive//Desktop//Phonepe//pulse//data//top//user//country//india//state//"
Agg_state_list=os.listdir(path)
Agg_state_list

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'User_Pincode':[], 'User_PincodeRegisteredUsers':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
              Pincode=z['name']
              PincoderegisteredUsers=z['registeredUsers']
              clm['User_Pincode'].append(Pincode)
              clm['User_PincodeRegisteredUsers'].append(PincoderegisteredUsers)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_User_Pincode=pd.DataFrame(clm)
Top_User_Pincode
# Out:
#                           State  Year  Quater User_Pincode  \
# 0     andaman-&-nicobar-islands  2018       1       744103
# 1     andaman-&-nicobar-islands  2018       1       744101
# 2     andaman-&-nicobar-islands  2018       1       744105
# 3     andaman-&-nicobar-islands  2018       1       744102
# 4     andaman-&-nicobar-islands  2018       1       744104
# ...                         ...   ...     ...          ...
# 9995                west-bengal  2024       4       733134
# 9996                west-bengal  2024       4       700059
# 9997                west-bengal  2024       4       711302
# 9998                west-bengal  2024       4       700150
# 9999                west-bengal  2024       4       711106
#
#       User_PincodeRegisteredUsers
# 0                            1608
# 1                            1108
# 2                            1075
# 3                            1006
# 4                             272
# ...                           ...
# ...

# %%
# Assigning datasets and Primary key list to the list to loop through data insertion into database
df_list = ['Agg_Transaction','Agg_Insurance','Agg_Users','Map_Transaction_Hover','Map_Insurance_Hover','Map_User_Hover',
           'Top_Trans_District','Top_Trans_Pincode','Top_Ins_District','Top_Ins_Pincode',
           'Top_User_District','Top_User_Pincode']
#PK_list = ['CustomerID','JourneyID','ReviewID','GeographyID','ProductID','EngagementID']

# %%
#Converting Dataframe into csv File to analyze the data
def save_csv(dfname):
    df = globals()[dfname]
    df.to_csv(f"C:\\Users\\conta\\OneDrive\\Desktop\\Phonepe\\csv\\{dfname}.csv", index=False)
                  
[csv for csv in [save_csv(i) for i in df_list]]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ### MYSQL CONNECTION ESTABLISHMENT

# %%
DB_NAME = "phonepe"

## Database connection
my_connection = pymysql.connect(host='127.0.0.1', user='root', passwd='mysql@123')
cursor = my_connection.cursor()

# Create Database if not exists
cursor.execute(f"CREATE DATABASE IF NOT EXISTS {DB_NAME}")
cursor.execute(f"USE {DB_NAME}")

# Define dtype mapping
dtype_mapping = {
    'int64': 'BIGINT',
    'float64': 'DOUBLE',
    'object': 'TEXT',
    'datetime64[ns]': 'DATETIME',
    'bool': 'BOOLEAN'
}

for datasetname in df_list:
    df = globals()[datasetname]
    
    # Map pandas dtypes to MySQL types
    dtype = [dtype_mapping[str(i)] for i in df.dtypes]
    table_column = ",".join(f"{i} {j}" for i, j in zip(df.columns, dtype))
    
    # Get table name
    table_name = datasetname
    
    # Create table
    cursor.execute(f"CREATE TABLE IF NOT EXISTS {table_name} ({table_column})")
    
    # Prepare SQL insert query
    columns = ", ".join(df.columns)
    placeholders = ", ".join(["%s"] * len(df.columns))
    sql_query = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
    
    # Convert DataFrame values into tuples
    data_tuples = [tuple(None if pd.isna(value) else value for value in row) for row in df.to_numpy()]
    
    # Insert data efficiently
    cursor.executemany(sql_query, data_tuples)
    my_connection.commit()

    print(f"Data successfully inserted into {table_name}")
# Out:
# Data successfully inserted into Agg_Transaction
# Data successfully inserted into Agg_Insurance
# Data successfully inserted into Agg_Users
# Data successfully inserted into Map_Transaction_Hover
# Data successfully inserted into Map_Insurance_Hover
# Data successfully inserted into Map_User_Hover
# Data successfully inserted into Top_Trans_District
# Data successfully inserted into Top_Trans_Pincode
# Data successfully inserted into Top_Ins_District
# Data successfully inserted into Top_Ins_Pincode
# Data successfully inserted into Top_User_District
# Data successfully inserted into Top_User_Pincode

# %%
my_connection.close()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import plotly.express as px
import plotly.io as pio
import nbformat
print(nbformat.__version__)
# Out:
# 5.10.4

# %% [markdown]
# ### Case 1:

# %%
#Case 1:
#Top 10 States by Total Transaction Value
q = "select State, sum(Transaction_amount) as 'Total Transaction Value' from agg_transaction group by State order by 2 DESC limit 10;"
df = pd.read_sql_query(q, my_connection)

df_sorted = df.sort_values(by='Total Transaction Value', ascending=False)

# Create the bar chart using seaborn
plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.barplot(x='State', y='Total Transaction Value', data=df_sorted)

# Add labels and title
plt.title('Total Transaction Value by State')
plt.xlabel('State')
plt.ylabel('Transaction Value (In Trillions)')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=45, ha="right")

# Format Y-axis to display in millions
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e12:.1f}T'))

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_23436\1151969973.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(q, my_connection)

# %%
#Payment Popular method
df = Agg_Transaction.groupby(['Transaction_type']).agg(total_trans_cnt=('Transaction_count','sum'),total_trans_amt=('Transaction_amount','sum'),).reset_index()

# Calculate the percentage for each category
df['tot_trans_cnt_pct'] = (df['total_trans_cnt'] / df['total_trans_cnt'].sum()) * 100
df['tot_trans_amt_pct'] = (df['total_trans_amt'] / df['total_trans_amt'].sum()) * 100

# Use a color palette from Matplotlib (Tab10 colors)
colors = ['#ADD8E6','#4169E1','#1E90FF','#0000CD','#4682B4']

# Create the pie chart
plt.figure(figsize=(4, 2))  # Set figure size for better visibility
df.plot(x="Transaction_type", y="tot_trans_cnt_pct", kind="pie",labels=df['Transaction_type'],autopct="%.2f%%", startangle=90, pctdistance=0.75, color=colors)

# Move the legend outside the plot
plt.legend(loc="upper left", bbox_to_anchor=(1.1, 1))


circle =  plt.Circle( (0,0), radius = 0.5, color='white')
plt.gca().add_artist(circle)
plt.gca().axes.get_yaxis().set_visible(False)

plt.title("Distribution of Transaction count by Payment Type")
plt.show()

# %%
# Create the pie chart
plt.figure(figsize=(4, 2))  # Set figure size for better visibility
df.plot(x="Transaction_type", y="tot_trans_amt_pct", kind="pie",labels=df['Transaction_type'],autopct="%.2f%%", startangle=90, pctdistance=0.5)

# Move the legend outside the plot
plt.legend(loc="upper left", bbox_to_anchor=(1.1,1))

plt.gca().axes.get_yaxis().set_visible(False)

plt.title("Distribution of Transaction Amount by Payment Type")
plt.show()

# %%
#Total Transaction Value by Payment Category
q = "select Transaction_type,sum(Transaction_amount) as 'Total Transaction Value' from agg_transaction where State = 'west-bengal' group by Transaction_type;"
df = pd.read_sql_query(q, my_connection)

# Create the bar chart using seaborn
plt.figure(figsize=(6, 4))  # Set figure size for better visibility
sns.lineplot(x='Transaction_type', y='Total Transaction Value', data=df)

# Add labels and title
plt.title('Total Transaction Value by Payment Category')
plt.xlabel('Payment Category')
plt.ylabel('Transaction Value (In Trillions)')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=45, ha="right")

# Format Y-axis to display in millions
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e12:.1f}T'))

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_23436\993340789.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(q, my_connection)

# %%
#Trend Analysis
Agg_Transaction['Year_Qtr'] = Agg_Transaction['Year'] + "_Q" + Agg_Transaction['Quater'].astype(str)

df = Agg_Transaction.groupby(['Year_Qtr']).agg(total_trans_amt=('Transaction_amount','sum')).reset_index()

# Create the bar chart using seaborn
plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.lineplot(x='Year_Qtr', y='total_trans_amt', data=df)

# Add labels and title
plt.title('Total Transaction Value Trend')
plt.xlabel('Year & Quarter')
plt.ylabel('Transaction Value (In Trillions)')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=45, ha="right")

# Format Y-axis to display in millions
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e12:.1f}T'))

# Show the plot
plt.tight_layout()
plt.show()

# %%
df = Agg_Transaction.groupby(['Year_Qtr']).agg(total_trans_amt=('Transaction_amount','sum')).reset_index()
px.line(df,x='Year_Qtr', y='total_trans_amt',
        labels={'Year_Qtr': 'Year & Quarter','total_trans_amt': 'Total Transaction Value'},
        title='Total Transaction Value Trend')

# %% [markdown]
# ### Case 2:

# %%
#2. Device Dominance and User Engagement Analysis
q = '''SELECT State, Year, Quater, SUM(RegisteredUsers) as 'Total Registered Users'
FROM (
    SELECT State, Year, Quater, RegisteredUsers,
           row_number() OVER (PARTITION BY State, Year, Quater ORDER BY RegisteredUsers) AS rownum
    FROM agg_users
) AS ranked_users
WHERE rownum = 1
GROUP BY State, Year, Quater;'''
df = pd.read_sql_query(q,my_connection)

# Create the bar chart using seaborn
plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.barplot(x='State', y='Total Registered Users', data=df)

# Add labels and title
plt.title('Total Registered Users by State')
plt.xlabel('State')
plt.ylabel('Total Registered Users (In Millions)')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=45, ha="right")

# Format Y-axis to display in millions
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\1593392295.py:10: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
q = '''select Users_brand, sum(Users_count) as 'Users Count' from agg_users where State = "maharashtra" group by Users_brand order by 2 DESC;'''
df = pd.read_sql_query(q,my_connection)

# Calculate the percentage for each category
df['tot_usr_cnt'] = (df['Users Count'] / df['Users Count'].sum()) * 100

# Create the pie chart
plt.figure(figsize=(10, 6))  # Set figure size for better visibility
df.plot(x="Users_brand", y="tot_usr_cnt", kind="pie",labels=df['Users_brand'],autopct="%.2f%%", startangle=90, pctdistance=0.5)

# Move the legend outside the plot
plt.legend(loc="upper left", bbox_to_anchor=(1.1, 1))
plt.gca().axes.get_yaxis().set_visible(False)

plt.title("Distribution of Users count by Device Type")
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\3156209913.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
# Calculate usage ratio for each device by state
#Agg_Users['Users_percentage'] = Agg_Users['Users_percentage'] / 100
plt.figure(figsize=(12, 7))
sns.barplot(x='State', y='Users_percentage', hue='Users_brand', data=Agg_Users, palette='Set2')

plt.title('Device Usage Ratio by State')
plt.xlabel('State')
plt.ylabel('Usage Ratio (Users Count / Registered Users)')
plt.xticks(rotation=45)

plt.legend(title='Device Type', loc='upper right')
plt.tight_layout()
plt.show()

# %%
#Plot usage ratio over time by device type
Agg_Users['Year_Qtr'] = Agg_Users['Year'] + "_Q" + Agg_Users['Quater'].astype(str)
plt.figure(figsize=(12, 7))
sns.lineplot(x='Year_Qtr', y='Users_percentage', hue='Users_brand', data=Agg_Users[Agg_Users['State'] == 'nagaland'], marker='o')

plt.title('Device Usage Ratio Over Time')
plt.xlabel('Year & Quarter')
plt.ylabel('Usage Ratio')
plt.xticks(rotation=45)
plt.legend(title='Device Type', loc='upper left', bbox_to_anchor=(1.1, 1))

plt.tight_layout()
plt.show()

# %%
# Filter for underutilized devices with a usage ratio < 0.3 (adjust threshold as needed)
underutilized_devices = Agg_Users[Agg_Users['Users_percentage'] < 10]

# Plot these underutilized devices
plt.figure(figsize=(14, 7))
sns.scatterplot(x='State', y='Users_brand', size='Users_percentage', data=underutilized_devices, 
                sizes=(10, 200), hue='Users_percentage')

plt.title('Underutilized Devices by State')
plt.xlabel('State')
plt.ylabel('Device Type')
plt.xticks(rotation=90)
plt.legend(title='Users Ratio', loc='upper left', bbox_to_anchor=(1.1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Case 3:

# %%
# Create the bar chart using seaborn
df = Map_Transaction_Hover[Map_Transaction_Hover['State'] == 'nagaland']
df1 = df.sort_values(by='Transaction_Hover_count', ascending=False)
plt.figure(figsize=(10, 6))  # Set figure size for better visibility

# Create the lineplot (for Transaction Hover Amount)
sns.lineplot(x='Transaction_Hover_name', y='Transaction_Hover_amount', data=df1, color='orange', marker='o')

# Add labels and title
plt.title('Total Transaction Amount by District')
plt.xlabel('District')
plt.ylabel('Total Transaction Amount')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=90, ha="left")

# Format the y-axes
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis

# Show the plot with tight layout
plt.tight_layout()
plt.show()

# %%
# Create the bar chart using seaborn
df = Map_Transaction_Hover[Map_Transaction_Hover['State'] == 'nagaland']
df1 = df.sort_values(by='Transaction_Hover_count', ascending=False)
plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.barplot(x='Transaction_Hover_name', y='Transaction_Hover_count', data=df1)

# Add labels and title
plt.title('Number of Transactions Counts by District')
plt.xlabel('District')
plt.ylabel('Number of Transactions Counts')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=90, ha="left")

# Format the y-axes
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis

# Show the plot with tight layout
plt.tight_layout()
plt.show()

# %%
#Plot usage ratio over time by device type
Map_Transaction_Hover['Year_Qtr'] = Map_Transaction_Hover['Year'] + "_Q" + Map_Transaction_Hover['Quater'].astype(str)
plt.figure(figsize=(12, 7))
sns.lineplot(x='Year_Qtr', y='Transaction_Hover_count', hue='Transaction_Hover_name', data=Map_Transaction_Hover[Map_Transaction_Hover['State'] == 'kerala'], marker='o')

plt.title('Transaction counts by Hover Over Time')
plt.xlabel('Year & Quarter')
plt.ylabel('Number of transactions')
plt.xticks(rotation=45)
plt.legend(title='Hover', loc='upper left', bbox_to_anchor=(1.1, 1))
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Case 4:

# %%
q = ''' Select District, sum(((App_Opens/ Registered_Users) * 100)) as App_Opens_Rate from map_user_hover
where State = "bihar"
Group by District order by 2 DESC;
'''
df = pd.read_sql_query(q,my_connection)
plt.figure(figsize=(14, 8))
sns.barplot(data=df, x='District', y='App_Opens_Rate', palette='viridis')
plt.title('App Open Rate by District')
plt.xlabel('District')
plt.ylabel('App Open Rate')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\2143937027.py:5: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\2143937027.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
q = ''' Select substr(District,1,instr(District,'District')-1) as Hover, concat(Year,"_Q",Quater) as Year_Qtr, sum(((App_Opens/ Registered_Users) * 100)) as App_Opens_Rate from map_user_hover
where State = "maharashtra"
Group by Hover, Year_Qtr order by App_Opens_Rate DESC;
'''
df = pd.read_sql_query(q,my_connection)
#df = df[df['App_Opens_Rate'] > 0.0]
plt.figure(figsize=(16, 8))
sns.lineplot(data=df, x='Year_Qtr', y='App_Opens_Rate', hue='Hover', marker='o')
plt.title('Trends in App Open Rate Over Time')
plt.xlabel('Quarter')
plt.ylabel('App Open Rate')
plt.xticks(rotation=60)
plt.legend(title='Hover', loc='upper left', bbox_to_anchor=(1.1, 1))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\89161431.py:5: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
# Create a 'first_quarter' column to capture the first quarter a user engaged
df = Map_User_Hover
# Create a 'first_quarter' column to capture the first quarter a user engaged
df['first_quarter'] = df.groupby('State')['Quater'].transform('min')
# Calculate retention as users who opened the app in subsequent quarters
retention = df[df['Quater'] > df['first_quarter']].groupby(['State', 'Year', 'Quater']).agg(
    returning_users=('Registered_Users', 'sum')
).reset_index()

# Merge retention data back with original data for better context
retention = pd.merge(retention, df, on=['State', 'Year', 'Quater'])

# Plot retention rate for a specific district
#district_retention = retention[retention['State'] == 'bihar']
plt.figure(figsize=(12, 6))
sns.lineplot(data=retention, x='Quater', y='returning_users',hue='State',marker='o')
plt.title('Retention of Users by State Over Quarters')
plt.xlabel('Quarter')
plt.ylabel('Retained Users')

plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis
plt.legend(title='Hover', loc='upper left', bbox_to_anchor=(1.1, 1))
plt.show()

# %% [markdown]
# ### Case 5: Transaction Analysis across States and Districts

# %%
q = ''' Select concat(substr(upper(State),1,1),substr(lower(State),2)) as State, sum(Transaction_District_count) as Transaction_Value
    from top_trans_district 
    group by State order by Transaction_Value DESC limit 10;
'''
df = pd.read_sql_query(q,my_connection)

plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.barplot(x='State', y='Transaction_Value', data=df)

# Add labels and title
plt.title('Total Transaction Value by State')
plt.xlabel('State')
plt.ylabel('Total Transaction Value')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=90, ha="left")

# Format the y-axes
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis

# Show the plot with tight layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\728553960.py:5: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
Top_Trans_District['Year_Qtr'] = Top_Trans_District['Year'] + "_Q" + Top_Trans_District['Quater'].astype(str)
df1 = Top_Trans_District.groupby(['State','Year_Qtr']).agg(tot_trans_cnt=('Transaction_District_count','sum')).reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1, x='Year_Qtr', y='tot_trans_cnt',hue='State',marker='o')
plt.title('Total Transaction Value Over Trend')
plt.xlabel('Year & Quarter')
plt.ylabel('Total Transaction Value')
plt.xticks(rotation=90)
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis
plt.legend(title='State', loc='upper left', bbox_to_anchor=(1.1, 1))
plt.show()

# %%
q = ''' Select concat(substr(upper(Transaction_District),1,1),substr(lower(Transaction_District),2)) as Transaction_District, 
    sum(Transaction_District_count) as Transaction_Value
    from top_trans_district 
    group by Transaction_District order by Transaction_Value DESC limit 10;
'''
df = pd.read_sql_query(q,my_connection)

plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.barplot(x='Transaction_District', y='Transaction_Value', data=df)

# Add labels and title
plt.title('Total Transaction Value by District')
plt.xlabel('District')
plt.ylabel('Total Transaction Value')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=90, ha="left")

# Format the y-axes
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis

# Show the plot with tight layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\361366492.py:6: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
Top_Trans_District['Year_Qtr'] = Top_Trans_District['Year'] + "_Q" + Top_Trans_District['Quater'].astype(str)
df1 = Top_Trans_District.groupby(['State','Transaction_District','Year_Qtr']).agg(tot_trans_cnt=('Transaction_District_count','sum')).reset_index()
df1 = df1[df1['State'] == 'kerala']
plt.figure(figsize=(12, 6))
sns.lineplot(data=df1, x='Year_Qtr', y='tot_trans_cnt',hue='Transaction_District',marker='o')
plt.title('Total Transaction Value Over Trend')
plt.xlabel('Year & Quarter')
plt.ylabel('Total Transaction Value')
plt.xticks(rotation=90)
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis
plt.legend(title='District', loc='upper left', bbox_to_anchor=(1.1, 1))
plt.show()

# %%
q = ''' Select concat(substr(upper(Transaction_Pincode),1,1),substr(lower(Transaction_Pincode),2)) as Transaction_Pincode, 
    sum(Transaction_Pincode_count) as Transaction_Value
    from top_trans_pincode
    group by Transaction_Pincode order by Transaction_Value DESC limit 10;
'''
df = pd.read_sql_query(q,my_connection)
df
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\1476575393.py:6: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Transaction_Pincode  Transaction_Value
# 0              500034       1.799788e+09
# 1              560001       1.508571e+09
# 2              500001       1.473824e+09
# 3              110006       1.266160e+09
# 4              411004       1.241541e+09
# 5              800001       8.706976e+08
# 6              302016       8.564585e+08
# 7              411033       7.886685e+08
# 8              500072       7.713284e+08
# 9              302012       7.695529e+08

# %%
q = ''' Select concat(substr(upper(Transaction_Pincode),1,1),substr(lower(Transaction_Pincode),2)) as Transaction_Pincode, 
    sum(Transaction_Pincode_amount) as Transaction_Volume
    from top_trans_pincode
    group by Transaction_Pincode order by Transaction_Volume DESC limit 10;
'''
df = pd.read_sql_query(q,my_connection)
df
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\721653209.py:6: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Transaction_Pincode  Transaction_Volume
# 0              500001        2.930982e+12
# 1              500034        2.777747e+12
# 2              560001        2.151967e+12
# 3              110006        1.890727e+12
# 4              411004        1.800762e+12
# 5              302016        1.528114e+12
# 6              800001        1.500670e+12
# 7              302012        1.165971e+12
# 8              462008        1.052087e+12
# 9              500072        1.026144e+12

# %% [markdown]
# ### Case 6: User Registration Analysis

# %%
# Create the bar chart using seaborn
q = ''' Select concat(substr(upper(State),1,1),substr(lower(State),2)) as State, sum(User_DistrictRegisteredUsers) as Total_Registered_Users
    from top_user_district 
    group by State order by Total_Registered_Users DESC limit 10;
'''
df = pd.read_sql_query(q,my_connection)

plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.barplot(x='State', y='Total_Registered_Users', data=df)

# Add labels and title
plt.title('Total Registered Users Counts by State')
plt.xlabel('State')
plt.ylabel('Total Registered Users')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=60, ha="left")

# Format the y-axes
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis

# Show the plot with tight layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\4092581736.py:6: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
Top_User_District['Year_Qtr'] = Top_User_District['Year'] + "_Q" + Top_User_District['Quater'].astype(str)
df1 = Top_User_District.groupby(['State','Year_Qtr']).agg(tot_reg_usr=('User_DistrictRegisteredUsers','sum')).reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1, x='Year_Qtr', y='tot_reg_usr',hue='State',marker='o')
plt.title('Total Registered Users Over Trend')
plt.xlabel('Year & Quarter')
plt.ylabel('Total Registered Users')
plt.xticks(rotation=90)
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis
plt.legend(title='State', loc='upper left', bbox_to_anchor=(1.1, 1))
plt.show()

# %%
# Create the bar chart using seaborn
q = ''' Select concat(substr(upper(User_District),1,1),substr(lower(User_District),2)) as District, sum(User_DistrictRegisteredUsers) as Total_Registered_Users
 from top_user_district
 group by District order by 2 DESC limit 10;
'''
df = pd.read_sql_query(q,my_connection)

plt.figure(figsize=(10, 6))  # Set figure size for better visibility
sns.barplot(x='District', y='Total_Registered_Users', data=df)

# Add labels and title
plt.title('Total Registered Users Counts by District')
plt.xlabel('District')
plt.ylabel('Total Registered Users')

# Rotate the x-axis labels if needed (in case of long state names)
plt.xticks(rotation=90, ha="left")

# Format the y-axes
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis

# Show the plot with tight layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\1893949438.py:6: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
Top_User_District['Year_Qtr'] = Top_User_District['Year'] + "_Q" + Top_User_District['Quater'].astype(str)
df1 = Top_User_District.groupby(['State','User_District','Year_Qtr']).agg(tot_reg_usr=('User_DistrictRegisteredUsers','sum')).reset_index()
df1 = df1[df1['State'] == 'kerala' ]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1, x='Year_Qtr', y='tot_reg_usr',hue='User_District',marker='o')
plt.title('Total Registered Users by District Over Trend')
plt.xlabel('Year & Quarter')
plt.ylabel('Total Registered Users')
plt.xticks(rotation=90)
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))  # Format for the left y-axis
plt.legend(title='User_District', loc='upper left', bbox_to_anchor=(1.1, 1))
plt.show()

# %%
# Create the bar chart using seaborn
q = ''' Select User_Pincode, sum(User_PincodeRegisteredUsers) as Total_Registered_Users
 from top_user_pincode
 where State = "kerala"
 group by User_Pincode order by 2 DESC limit 10;
'''
df = pd.read_sql_query(q,my_connection)
df
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_18448\3356835581.py:7: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   User_Pincode  Total_Registered_Users
# 0       682024               1006953.0
# 1       695001                990672.0
# 2       682042                910582.0
# 3       682025                888948.0
# 4       682020                733658.0
# 5       670645                732388.0
# 6       682035                688741.0
# 7       682032                650526.0
# 8       673592                631248.0
# 9       682301                510264.0
